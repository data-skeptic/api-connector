# %% [markdown]
# ### Example: Pushing data
# Very basic example. Assumes you have a local version of the app running and have created the user.
# To push data to the public server, https://home-sales-data-api.herokuapp.com/ You must request access.

# %%
import requests
def get_token(username, password):
    baseurl = 'http://127.0.0.1:8000'
    data = {"username":username, 
            "password":password}
    r = requests.post(baseurl + '/token/auth/', data = data)
    return r.json()['token']
    
token = get_token('JohnDoe', 'SuperSecure')
print(token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoyLCJlbWFpbCI6IiIsImV4cCI6MTQ2MTg5NDA5NCwidXNlcm5hbWUiOiJKb2huRG9lIn0.pfSnTlLxj-YGy2XzJrTSRa7ujoSOA-UOBgAQFs6nXqU

# %%
from datetime import datetime
baseurl = 'http://127.0.0.1:8000'
headers = {"Authorization": "Bearer " + token}

data = {"listing_timestamp": str(datetime.now()),
        "listing_type": 'F', # for sale
        "price": 123456,
        "size_units": 'I',
        "raw_address": "1701 Wynkoop St, Denver, CO 80202"
       }

r = requests.post(baseurl + '/api/property/', data = data, headers=headers)
r.json()
# Out:
# {'bathrooms': None,
#  'bedrooms': None,
#  'building_size': None,
#  'car_spaces': None,
#  'features': [],
#  'geocoded_address': '',
#  'id': 22691,
#  'land_size': None,
#  'listing_timestamp': '2016-04-28T19:36:37.114241Z',
#  'listing_type': 'F',
#  'price': 123456.0,
#  'raw_address': '1701 Wynkoop St, Denver, CO 80202',
#  'size_units': 'I',
#  'submitter': None,
#  'upload_timestamp': '2016-04-29T01:36:37.122624Z',
#  'valid': False}

# %% [markdown]
# ### Example: Fetching select (filtered) data.
# Very basic example using the public API at https://home-sales-data-api.herokuapp.com/

# %%
# Example: fetching data.
from datetime import datetime
from random import random

baseurl = 'https://home-sales-data-api.herokuapp.com/'
data = {'min_price': '150000',
          'max_price': '200000',
          'min_bedrooms': '1',
          'max_bedrooms': '3',
          'min_bathrooms': '1',
          'max_bathrooms': '2',
          'min_car_spaces': '1',
          'max_car_spaces': '2',
          'address_contains': 'main'
          }


r = requests.get(baseurl + '/api/property/', data = data)
r.json()
# Out:
# [{'bathrooms': 2.0,
#   'bedrooms': 3.0,
#   'building_size': 1400.0,
#   'car_spaces': 1.0,
#   'features': [],
#   'geocoded_address': '123 Main St, Schenevus, NY 12155, USA',
#   'id': 1,
#   'land_size': 2000.0,
#   'listing_timestamp': '2016-03-31T21:09:00Z',
#   'listing_type': 'F',
#   'price': 123456.0,
#   'raw_address': '123 Main St.',
#   'size_units': 'M',
#   'upload_timestamp': '2016-04-05T02:46:50.380670Z'},
#  {'bathrooms': 0.0,
#   'bedrooms': 0.0,
#   'building_size': 10.0,
#   'car_spaces': None,
#   'features': [],
#   'geocoded_address': '123 Test Rd, Richmond, IN 47374, USA',
#   'id': 2,
#   'land_size': 20.0,
#   'listing_timestamp': '2016-04-05T02:57:20.059246Z',
#   'listing_type': 'F',
#   'price': 1.0,
#   'raw_address': '123 Test Ave',
#   'size_units': 'M',
#   'upload_timestamp': '2016-04-05T02:57:20.785874Z'},
#  {'bathrooms': 0.0,
#   'bedrooms': 0.0,
#   'building_size': 10.0,
#   'car_spaces': None,
#   'features': [],
# ...
